# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("Mall_Customers.csv")
df
# Out:
#      CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83
#
# [200 rows x 5 columns]

# %%
df.dtypes
# Out:
# CustomerID                 int64
# Genre                     object
# Age                        int64
# Annual Income (k$)         int64
# Spending Score (1-100)     int64
# dtype: object

# %%
#To calculate mean
df.select_dtypes(include='number').mean()
# Out:
# CustomerID                100.50
# Age                        38.85
# Annual Income (k$)         60.56
# Spending Score (1-100)     50.20
# dtype: float64

# %%
df.loc[:,'Age'].mean()
# Out:
# 38.85

# %%
df.select_dtypes(include = 'number').mean(axis = 1)[0:4]
# Out:
# 0    18.50
# 1    29.75
# 2    11.25
# 3    30.00
# dtype: float64

# %%
#To find median
df.select_dtypes(include = 'number').median()
# Out:
# CustomerID                100.5
# Age                        36.0
# Annual Income (k$)         61.5
# Spending Score (1-100)     50.0
# dtype: float64

# %%
df.loc[:,'Age'].median()
# Out:
# 36.0

# %%
df.select_dtypes(include='number').mevdian(axis =1)[0:4]
# Out:
# 0    17.0
# 1    18.0
# 2    11.0
# 3    19.5
# dtype: float64

# %%
df.loc[:,'Age'].mode()
# Out:
# 0    32
# Name: Age, dtype: int64

# %%
#To find minimum of all columns

df.min()
# Out:
# CustomerID                     1
# Genre                     Female
# Age                           18
# Annual Income (k$)            15
# Spending Score (1-100)         1
# dtype: object

# %%
#To find maximum
df.max()
# Out:
# CustomerID                 200
# Genre                     Male
# Age                         70
# Annual Income (k$)         137
# Spending Score (1-100)      99
# dtype: object

# %%
#To find standard deviation
df.loc[:,'Age'].std()
# Out:
# 13.96900733155888

# %%
df.select_dtypes(include = 'number').std(axis = 1)[0:4]
# Out:
# 0    15.695010
# 1    35.074920
# 2     8.057088
# 3    32.300671
# dtype: float64

# %%
#Categorical : Age
#Quantative : Income

df.groupby(['Genre'])['Age'].mean()
# Out:
# Genre
# Female    38.098214
# Male      39.806818
# Name: Age, dtype: float64

# %%
df_u = df.rename(columns= {'Annual Income (k$)':'Income'},inplace = False)

df_u.groupby(['Genre']).Income.mean()
# Out:
# Genre
# Female    59.250000
# Male      62.227273
# Name: Income, dtype: float64

# %%
df.groupby(['Genre']) ['Annual Income (k$)'].max()
# Out:
# Genre
# Female    126
# Male      137
# Name: Annual Income (k$), dtype: int64

# %%
df.groupby(['Genre']) ['Annual Income (k$)'].min()
# Out:
# Genre
# Female    16
# Male      15
# Name: Annual Income (k$), dtype: int64

# %%
df.groupby(['Genre']) ['Spending Score (1-100)'].max()
# Out:
# Genre
# Female    99
# Male      97
# Name: Spending Score (1-100), dtype: int64

# %%
df.groupby(['Genre']) ['Spending Score (1-100)'].min()
# Out:
# Genre
# Female    5
# Male      1
# Name: Spending Score (1-100), dtype: int64
